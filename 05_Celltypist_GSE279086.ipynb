# %%
# !pip install scanpy
# !pip install celltypist
# !pip install anndata scanpy

# %%
# %pip install -U typing_extensions
# !pip install ipywidgets
# Out:
# Requirement already satisfied: typing_extensions in /home/israa/miniconda3/lib/python3.13/site-packages (4.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: ipywidgets in /home/israa/miniconda3/lib/python3.13/site-packages (8.1.9)
# Requirement already satisfied: comm>=0.1.3 in /home/israa/miniconda3/lib/python3.13/site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in /home/israa/miniconda3/lib/python3.13/site-packages (from ipywidgets) (9.16.1)
# Requirement already satisfied: traitlets>=4.3.1 in /home/israa/miniconda3/lib/python3.13/site-packages (from ipywidgets) (5.16.1)
# Requirement already satisfied: widgetsnbextension~=4.0.16 in /home/israa/miniconda3/lib/python3.13/site-packages (from ipywidgets) (4.0.16)
# Requirement already satisfied: jupyterlab_widgets~=3.0.17 in /home/israa/miniconda3/lib/python3.13/site-packages (from ipywidgets) (3.0.17)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /home/israa/miniconda3/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in /home/israa/miniconda3/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (0.20.0)
# Requirement already satisfied: matplotlib-inline>=0.1.6 in /home/israa/miniconda3/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: pexpect>4.6 in /home/israa/miniconda3/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/israa/miniconda3/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.53)
# Requirement already satisfied: psutil>=7 in /home/israa/miniconda3/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (7.2.2)
# Requirement already satisfied: pygments>=2.14.0 in /home/israa/miniconda3/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (2.19.1)
# Requirement already satisfied: stack_data>=0.6.0 in /home/israa/miniconda3/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: wcwidth>=0.1.4 in /home/israa/miniconda3/lib/python3.13/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.8.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /home/israa/miniconda3/lib/python3.13/site-packages (from jedi>=0.18.2->ipython>=6.1.0->ipywidgets) (0.8.7)
# Requirement already satisfied: ptyprocess>=0.5 in /home/israa/miniconda3/lib/python3.13/site-packages (from pexpect>4.6->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /home/israa/miniconda3/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/israa/miniconda3/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (3.0.2)
# Requirement already satisfied: pure_eval in /home/israa/miniconda3/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (0.2.3)

# %%
import pandas as pd
import numpy as np
import anndata as ad
import scanpy as sc
import celltypist
import os

# %%
import warnings
warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)

# %%
os.getcwd()
# Out:
# '/home/israa/GSE279086_scRNA-seq_analysis'

# %%
GSE279086_raw_adata = ad.read_h5ad("output/03_GSE279086_seurat_pca_umap.h5ad")
GSE279086_raw_adata
# Out:
# AnnData object with n_obs × n_vars = 6327 × 16832
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'sample', 'percent.mt', 'percent.rb', 'Condition', 'Sample', 'mahal_dist_nCount', 'pca_clusters', 'ident'
#     uns: 'X_name'
#     obsm: 'PCA', 'UMAP'
#     layers: 'logcounts', None (.X)

# %%
GSE279086_harmony_adata = ad.read_h5ad("output/04_GSE279086_harmony_corrected.h5ad")
GSE279086_harmony_adata
# Out:
# AnnData object with n_obs × n_vars = 6327 × 16832
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'sample', 'percent.mt', 'percent.rb', 'Condition', 'Sample', 'mahal_dist_nCount', 'pca_clusters', 'harmony_nn_res.0.8', 'seurat_clusters', 'ident'
#     uns: 'X_name'
#     obsm: 'HARMONY', 'PCA', 'UMAP'
#     layers: 'logcounts', None (.X)

# %%
# Load Seurat UMAP coordinates
umap_df = pd.read_csv(
    "output/GSE279086_umap_coordinates.csv",
    index_col=0
)

# Sanity check
print(umap_df.shape)   # should be (6327, 2)

# Inject into AnnData
GSE279086_harmony_adata.obsm['X_umap'] = umap_df.loc[
    GSE279086_harmony_adata.obs_names
].values

sc.pl.umap(
    GSE279086_harmony_adata,
    color='seurat_clusters',
    show=True
)
# Out:
# (6327, 2)

# %%
# Put log-normalized counts into X (only for CellTypist)
GSE279086_harmony_adata.X = GSE279086_harmony_adata.layers['logcounts'].copy()

# %%
##---Two step Leiden method---
## much tighter in cluster
import scanpy as sc

sc.pp.neighbors(GSE279086_harmony_adata)
sc.tl.leiden(GSE279086_harmony_adata, resolution=1)

# %%
ct_pred = celltypist.annotate(
    GSE279086_harmony_adata,
    model="Adult_Human_Kidney.pkl",
    over_clustering=GSE279086_harmony_adata.obs["leiden"],
    majority_voting=True
)
# Out:
# 🔬 Input data has 6327 cells and 16832 genes
# 🔗 Matching reference genes in the model
# 🧬 9156 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!

# %%
GSE279086_harmony_adata.obs['majority_voting'] = (
    ct_pred.predicted_labels['majority_voting']
    .astype(str)
)

# %%
print(GSE279086_harmony_adata.obs['majority_voting'].value_counts().head())
# Out:
# majority_voting
# PC        1462
# EC-PTC    1334
# DTL        564
# VSMC/P     508
# EC-DVR     420
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

for cond in GSE279086_harmony_adata.obs['Condition'].unique():
    fig = sc.pl.umap(
        GSE279086_harmony_adata[
            GSE279086_harmony_adata.obs['Condition'] == cond
        ],
        color='majority_voting',
        title=f'Condition: {cond}',
        legend_loc='right margin',
        show=False,
        return_fig=True
    )
    plt.savefig(
        f"plots/celltypist_plots/umap_celltypes_ct_{cond}.png",
        dpi=300,
        bbox_inches='tight'
    )
    plt.show()
# Out:
# ... storing 'majority_voting' as categorical
# ... storing 'majority_voting' as categorical

# %%
# Move log-normalized expression into X for CellTypist
GSE279086_raw_adata.X = GSE279086_raw_adata.layers['logcounts'].copy()

sc.pp.neighbors(GSE279086_raw_adata)
sc.tl.leiden(GSE279086_raw_adata, resolution=1)

GSE279086_predictions3 = celltypist.annotate(
    GSE279086_raw_adata, 
    model='Adult_Human_Kidney.pkl',
    over_clustering=GSE279086_raw_adata.obs["leiden"],
    majority_voting=True
)

# Save majority voting to obs
GSE279086_raw_adata.obs["majority_voting"] = GSE279086_predictions3.predicted_labels["majority_voting"].astype(str)
# Out:
# 🔬 Input data has 6327 cells and 16832 genes
# 🔗 Matching reference genes in the model
# 🧬 9156 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!

# %%
import seaborn as sns

# Step 1: Count cells per cell type per condition
n_cells_condition = (
    GSE279086_raw_adata.obs
    .groupby(["Condition", "majority_voting"])
    .size()
    .reset_index(name="count")
)

# Step 2: Calculate proportions per condition
n_cells_condition["total"] = n_cells_condition.groupby("Condition")["count"].transform("sum")
n_cells_condition["proportion"] = (n_cells_condition["count"] / n_cells_condition["total"]) * 100

# Step 3: Compute average proportion per cell type for ordering
avg_proportions = (
    n_cells_condition
    .groupby("majority_voting")["proportion"]
    .mean()
    .sort_values(ascending=False)
)
ordered_celltypes = avg_proportions.index.tolist()

# Step 4: Plot
plt.figure(figsize=(40, 10))
ax = sns.barplot(
    data=n_cells_condition,
    x="majority_voting",
    y="proportion",
    hue="Condition",
    order=ordered_celltypes,
    dodge=True,
    width=0.9
)

# Step 5: Add proportion labels
for container in ax.containers:
    ax.bar_label(container, fmt='%.1f%%', label_type='edge', padding=2, fontsize=10, rotation = 90)

# Customize axes
plt.xticks(rotation=45, ha="right", fontsize=12, fontweight="bold")
plt.ylabel("Proportion (%)", fontsize=12, fontweight="bold")
plt.xlabel("Cell Type", fontsize=12, fontweight="bold")
plt.title("Cell Type Proportions", fontsize=14, fontweight="bold")
plt.tight_layout()
plt.savefig("plots/celltypist_plots/Cellproportions_barplot.png", dpi=400, bbox_inches='tight')
plt.show()

n_cells_condition.to_csv("output/GSE279086_Cellproportions.csv", index=False)

# %%
# Create combined group label FIRST
GSE279086_raw_adata.obs['majority_voting'] = (
    GSE279086_raw_adata.obs['majority_voting'].astype(str)
    + "_" +
    GSE279086_raw_adata.obs['Condition'].astype(str)
)

# %%
def find_unique_markers(
    adata, 
    groupby='cell_type', 
    method='wilcoxon', 
    pval_threshold=0.05, 
    logfc_threshold=0.25,
    top_n=3,
    min_cells_per_group=2
):
    """
    Mimics Seurat's FindAllMarkers + filters for unique DEGs per cluster.
    
    Parameters:
        adata : AnnData object
        groupby : column in adata.obs to group cells (e.g., clusters, cell_type)
        method : DEG test method ('wilcoxon', 't-test', 'logreg')
        pval_threshold : adjusted p-value threshold for significance
        logfc_threshold : log fold change threshold for filtering

    Returns:
        unique_degs_df : DataFrame of DEGs unique to each group
    """

    # Filter out low-cell groups
    group_counts = adata.obs[groupby].value_counts()
    valid_groups = group_counts[group_counts >= min_cells_per_group].index.tolist()

    # Subset AnnData to valid groups only
    adata_filtered = adata[adata.obs[groupby].isin(valid_groups)].copy()
    
    # Run DEG analysis
    sc.tl.rank_genes_groups(adata_filtered, groupby=groupby, method=method)
    
    # Get full results into a DataFrame
    all_degs = sc.get.rank_genes_groups_df(adata_filtered, group=None)
    
    # Filter by significance
    filtered_degs = all_degs[
        (all_degs['pvals_adj'] < pval_threshold) &
        (abs(all_degs['logfoldchanges']) > logfc_threshold)
    ]

    # Find genes that appear in only one group
    unique_genes = (
        filtered_degs.groupby('names')['group']
        .nunique()
        .reset_index()
        .query('group == 1')['names']
        .tolist()
    )

    # Keep only unique DEGs
    unique_degs_df = filtered_degs[filtered_degs['names'].isin(unique_genes)].copy()


    # Select top N per group by logFC
    top_unique_degs_df = (
        unique_degs_df
        .sort_values(['group', 'logfoldchanges'], ascending=[True, False])
        .groupby('group')
        .head(top_n)
        .reset_index(drop=True)
    )

    return top_unique_degs_df

# %%
unique_markers = find_unique_markers(
    GSE279086_raw_adata, 
    groupby='majority_voting',
    method='wilcoxon',
    pval_threshold=0.05, 
    logfc_threshold=0.25,
    top_n=3, 
    min_cells_per_group=2
)

unique_markers['group'] = (
    unique_markers['group']
    .str.replace(r'_(Control|Type 1 Diabetes)_\1$', r'_\1', regex=True)
)

# Inspect & save
print(unique_markers.head())
unique_markers['group'].drop_duplicates()

unique_markers.to_csv("output/GSE279086_Unique_cluster_markers.csv", index=False)
# Out:
# ... storing 'majority_voting' as categorical
#                    group    names    scores  logfoldchanges     pvals  \
# 0          C-TAL_Control     GRM1  3.322196        4.248542  0.000893
# 1          C-TAL_Control    CABP1  3.059159        3.971456  0.002220
# 2          C-TAL_Control   SH3D21  3.393136        3.448381  0.000691
# 3  C-TAL_Type 1 Diabetes    CRIP3  3.078203        5.386682  0.002083
# 4  C-TAL_Type 1 Diabetes  TMEM207  3.323988        4.893994  0.000887
#
#    pvals_adj
# 0   0.016611
# 1   0.035480
# 2   0.013461
# 3   0.032288
# 4   0.015941

# %%
import pandas as pd
import scanpy as sc
import matplotlib.pyplot as plt
import numpy as np

excluded_prefixes = ["Classical monocytes"]
mask = ~GSE279086_raw_adata.obs['majority_voting'].str.startswith(tuple(excluded_prefixes))
adata_to_plot = GSE279086_raw_adata[mask].copy()

genes_to_plot = unique_markers["names"].tolist()  # top 3 per group
# Keep only genes that exist in adata.var_names
genes_to_plot = [g for g in genes_to_plot if g in adata_to_plot.var_names]

X = adata_to_plot[:, genes_to_plot].X
if hasattr(X, "toarray"):  # sparse -> dense
    X = X.toarray()

# Make a DataFrame: rows = cell types, columns = genes
expr_df = pd.DataFrame(X, index=adata_to_plot.obs['majority_voting'], columns=genes_to_plot)

expr_per_group = expr_df.groupby(expr_df.index).sum()  # rows = groups, columns = genes

# Keep only genes where max across groups ≥ 30
genes_filtered = expr_per_group.columns[(expr_per_group.max(axis=0) >= 30)].tolist()

# Filter expression DataFrame
expr_per_group = expr_per_group[genes_filtered]

valid_groups = expr_per_group.index[(expr_per_group.sum(axis=1) > 20)].tolist()
adata_to_plot = adata_to_plot[adata_to_plot.obs['majority_voting'].isin(valid_groups)].copy()

sc.pl.dotplot(
    adata_to_plot,
    var_names=genes_filtered,
    groupby='majority_voting',
    standard_scale='var',
    show=False,
    figsize=(20, 20),
    dendrogram=False
)
plt.savefig("plots/celltypist_plots/GSE279086_Cluster_Markergenes.png", dpi=400, bbox_inches='tight')
plt.show()
# Out:
# ... storing 'majority_voting' as categorical

# %%
GSE279086_raw_adata.write("output/GSE279086_celltypist.h5ad")
# Out:
# ... storing 'majority_voting' as categorical
